# %%
# import base packages
import pandas as pd
import requests
import os

# %%
# Get the station data in the API
url='https://gbfs.divvybikes.com/gbfs/en/station_information.json'
r = requests.get(url)
json = r.json()
station = pd.DataFrame(json['data']['stations'])
station.head()
# Out:
#   eightd_station_services station_type  electric_bike_surcharge_waiver  \
# 0                      []      classic                           False
# 1                      []      classic                           False
# 2                      []      classic                           False
# 3                      []      classic                           False
# 4                      []      classic                           False
#
#    capacity        lat        lon  \
# 0        27  41.925602 -87.653708
# 1        15  41.780531 -87.605970
# 2        15  41.648501 -87.546090
# 3        19  41.842052 -87.617000
# 4        11  41.765508 -87.616918
#
#                                          rental_uris    short_name legacy_id  \
# 0  {'ios': 'https://chi.lft.to/lastmile_qr_scan',...  TA1306000016        67
# 1  {'ios': 'https://chi.lft.to/lastmile_qr_scan',...  KA1503000054       427
# 2  {'ios': 'https://chi.lft.to/lastmile_qr_scan',...         20215       732
# 3  {'ios': 'https://chi.lft.to/lastmile_qr_scan',...  TA1307000139       237
# 4  {'ios': 'https://chi.lft.to/lastmile_qr_scan',...         15599       393
#
#    has_kiosk  ...                           external_id  \
# 0       True  ...  a3a4ac3f-a135-11e9-9cda-0a87ae2ba916
# 1       True  ...  a3ad95a7-a135-11e9-9cda-0a87ae2ba916
# 2       True  ...  ff21c158-de98-46c6-9ef7-7082bdb7c634
# 3       True  ...  a3a859c4-a135-11e9-9cda-0a87ae2ba916
# 4       True  ...  a3acea44-a135-11e9-9cda-0a87ae2ba916
#
#                             name region_id  \
# 0  Sheffield Ave & Fullerton Ave       NaN
# 1    Cottage Grove Ave & 63rd St       NaN
# 2        Hegewisch Metra Station       NaN
# 3            MLK Jr Dr & 29th St       NaN
# 4          Calumet Ave & 71st St       NaN
#
#   dockless_bikes_parking_zone_capacity region_code address  rack_model  \
# 0                                  NaN         NaN     NaN         NaN
# 1                                  NaN         NaN     NaN         NaN
# 2                                  NaN         NaN     NaN         NaN
# 3                                  NaN         NaN     NaN         NaN
# 4                                  NaN         NaN     NaN         NaN
#
#   client_station_id target_bike_capacity target_scooter_capacity
# 0               NaN                  NaN                     NaN
# 1               NaN                  NaN                     NaN
# 2               NaN                  NaN                     NaN
# 3               NaN                  NaN                     NaN
# 4               NaN                  NaN                     NaN
#
# [5 rows x 23 columns]

# %%
# Check the station_df columns
station.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1422 entries, 0 to 1421
# Data columns (total 23 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   eightd_station_services               1422 non-null   object
#  1   station_type                          1422 non-null   object
#  2   electric_bike_surcharge_waiver        1422 non-null   bool
#  3   capacity                              1422 non-null   int64
#  4   lat                                   1422 non-null   float64
#  5   lon                                   1422 non-null   float64
#  6   rental_uris                           1422 non-null   object
#  7   short_name                            684 non-null    object
#  8   legacy_id                             1422 non-null   object
#  9   has_kiosk                             1422 non-null   bool
#  10  station_id                            1422 non-null   object
#  11  eightd_has_key_dispenser              1422 non-null   bool
#  12  rental_methods                        684 non-null    object
#  13  external_id                           1422 non-null   object
#  14  name                                  1422 non-null   object
#  15  region_id                             14 non-null     object
#  16  dockless_bikes_parking_zone_capacity  738 non-null    float64
#  17  region_code                           738 non-null    object
#  18  address                               738 non-null    object
#  19  rack_model                            738 non-null    object
#  20  client_station_id                     738 non-null    object
#  21  target_bike_capacity                  10 non-null     float64
#  22  target_scooter_capacity               10 non-null     float64
# dtypes: bool(3), float64(5), int64(1), object(14)
# memory usage: 226.5+ KB

# %%
# export the data to a csv file
os.makedirs('raw_data', exist_ok=True)  
station.to_csv('raw_data/station_API.csv')

# %%
# test the get_station_data function
from ml_logic.data_import import get_station_data

df = get_station_data()
df
# Out:
#       Unnamed: 0                           external_id  \
# 0              0  a3b1c47b-a135-11e9-9cda-0a87ae2ba916
# 1              1  a3b2d2b7-a135-11e9-9cda-0a87ae2ba916
# 2              2  a3b20960-a135-11e9-9cda-0a87ae2ba916
# 3              3  a3a5f5e6-a135-11e9-9cda-0a87ae2ba916
# 4              4  a3a795d7-a135-11e9-9cda-0a87ae2ba916
# ...          ...                                   ...
# 1417        1417      motivate_CHI_1715846688321143644
# 1418        1418      motivate_CHI_1715823822654071770
# 1419        1419      motivate_CHI_1563698701206292480
# 1420        1420      motivate_CHI_1674190591734328324
# 1421        1421      motivate_CHI_1674190634684001360
#
#                                 station_id short_name  \
# 0     a3b1c47b-a135-11e9-9cda-0a87ae2ba916      16915
# 1     a3b2d2b7-a135-11e9-9cda-0a87ae2ba916        593
# 2     a3b20960-a135-11e9-9cda-0a87ae2ba916        554
# 3     a3a5f5e6-a135-11e9-9cda-0a87ae2ba916      13162
# 4     a3a795d7-a135-11e9-9cda-0a87ae2ba916      13036
# ...                                    ...        ...
# 1417                   1715846688321143644        NaN
# 1418                   1715823822654071770        NaN
# 1419                   1563698701206292480        NaN
# 1420                   1674190591734328324        NaN
# 1421                   1674190634684001360        NaN
#
#       eightd_has_key_dispenser            legacy_id  \
# 0                        False                  541
# 1                        False                  593
# 2                        False                  554
# 3                        False                  135
# 4                        False                  197
# ...                        ...                  ...
# 1417                     False  1715846688321143644
# 1418                     False  1715823822654071770
# 1419                     False  1563698701206292480
# 1420                     False  1674190591734328324
# 1421                     False  1674190634684001360
#
#       electric_bike_surcharge_waiver  capacity  has_kiosk  \
# 0                              False        11       True
# 1                              False        11       True
# 2                              False         7       True
# 3                              False        11       True
# 4                              False        19       True
# ...                              ...       ...        ...
# 1417                           False         1      False
# 1418                           False         1      False
# 1419                           False         9      False
# 1420                           False         2      False
# 1421                           False         2      False
#
#                             rental_methods  ... station_type  \
# 0     ['KEY', 'CREDITCARD', 'TRANSITCARD']  ...      classic
# 1     ['KEY', 'CREDITCARD', 'TRANSITCARD']  ...      classic
# 2     ['KEY', 'CREDITCARD', 'TRANSITCARD']  ...      classic
# 3     ['KEY', 'CREDITCARD', 'TRANSITCARD']  ...      classic
# 4     ['KEY', 'CREDITCARD', 'TRANSITCARD']  ...      classic
# ...                                    ...  ...          ...
# 1417                                   NaN  ...  lightweight
# 1418                                   NaN  ...  lightweight
# 1419                                   NaN  ...  lightweight
# 1420                                   NaN  ...  lightweight
# 1421                                   NaN  ...  lightweight
#
#       eightd_station_services region_id  region_code  \
# 0                          []       NaN          NaN
# 1                          []       NaN          NaN
# 2                          []       NaN          NaN
# 3                          []       NaN          NaN
# 4                          []       NaN          NaN
# ...                       ...       ...          ...
# 1417                       []       NaN          CHI
# 1418                       []       NaN          CHI
# 1419                       []       NaN          CHI
# 1420                       []       NaN          CHI
# 1421                       []       NaN          CHI
#
#                                                 address  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1417  2609, West Division Street, West Town, Chicago...
# 1418  2237, West 50th Place, Gage Park, Chicago, Lak...
# 1419  3218-3220, North Lamon Avenue, Portage Park, C...
# 1420  Dr. Martin Luther King, Jr. Family Entertainme...
# 1421  Susan B. Anthony Elementary School, East 99th ...
#
#      dockless_bikes_parking_zone_capacity        rack_model  \
# 0                                     NaN               NaN
# 1                                     NaN               NaN
# 2                                     NaN               NaN
# 3                                     NaN               NaN
# 4                                     NaN               NaN
# ...                                   ...               ...
# 1417                                  1.0  CITY_PUBLIC_RACK
# 1418                                  1.0  CITY_PUBLIC_RACK
# 1419                                  9.0   CITY_PILOT_RACK
# 1420                                  2.0  CITY_PUBLIC_RACK
# 1421                                  2.0  CITY_PUBLIC_RACK
#
#                      client_station_id target_bike_capacity  \
# 0                                  NaN                  NaN
# 1                                  NaN                  NaN
# 2                                  NaN                  NaN
# 3                                  NaN                  NaN
# 4                                  NaN                  NaN
# ...                                ...                  ...
# 1417  motivate_CHI_1715846688321143644                  NaN
# 1418  motivate_CHI_1715823822654071770                  NaN
# 1419  motivate_CHI_1563698701206292480                  NaN
# 1420  motivate_CHI_1674190591734328324                  NaN
# 1421  motivate_CHI_1674190634684001360                  NaN
#
#       target_scooter_capacity
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 1417                      NaN
# 1418                      NaN
# 1419                      NaN
# 1420                      NaN
# 1421                      NaN
#
# [1422 rows x 24 columns]
