# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import os
import datetime as dt

# %% [markdown]
# # Divvy Dataset

# %% [markdown]
# Reading the Divvy dataset and converting time data to hourly intervals
#
# Last column: hourly_data

# %%
path = '/Users/joachimclodic/code/G-Dolle/DIVVY_BIKE/raw_data/Divvy_Trips_2021_Q1.csv'

df=pd.read_csv(path)
df['started_at']=pd.to_datetime(df['started_at'])
df['ended_at']=pd.to_datetime(df['ended_at'])
df['hourly_data'] = df.started_at.dt.round('60min')
df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  E19E6F1B8D4C42ED  electric_bike 2021-01-23 16:14:19 2021-01-23 16:24:44
# 1  DC88F20C2C55F27F  electric_bike 2021-01-27 18:43:08 2021-01-27 18:47:12
# 2  EC45C94683FE3F27  electric_bike 2021-01-21 22:35:54 2021-01-21 22:37:14
# 3  4FA453A75AE377DB  electric_bike 2021-01-07 13:31:13 2021-01-07 13:42:55
# 4  BE5E8EB4E7263A0B  electric_bike 2021-01-23 02:24:02 2021-01-23 02:24:45
#
#            start_station_name start_station_id end_station_name  \
# 0  California Ave & Cortez St            17660              NaN
# 1  California Ave & Cortez St            17660              NaN
# 2  California Ave & Cortez St            17660              NaN
# 3  California Ave & Cortez St            17660              NaN
# 4  California Ave & Cortez St            17660              NaN
#
#   end_station_id  start_lat  start_lng  end_lat  end_lng member_casual  \
# 0            NaN  41.900341 -87.696743    41.89   -87.72        member
# 1            NaN  41.900333 -87.696707    41.90   -87.69        member
# 2            NaN  41.900313 -87.696643    41.90   -87.70        member
# 3            NaN  41.900399 -87.696662    41.92   -87.69        member
# 4            NaN  41.900326 -87.696697    41.90   -87.70        casual
#
#           hourly_data
# 0 2021-01-23 16:00:00
# 1 2021-01-27 19:00:00
# 2 2021-01-21 23:00:00
# 3 2021-01-07 14:00:00
# 4 2021-01-23 02:00:00

# %%
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at            datetime64[ns]
# ended_at              datetime64[ns]
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# hourly_data           datetime64[ns]
# dtype: object

# %% [markdown]
# # Weather Dataset

# %% [markdown]
# Reading the Weather dataset and converting time data to the same format as the Divvy Dataset
#
# Last column: hourly_data

# %%
path_weather= '/Users/joachimclodic/code/G-Dolle/DIVVY_BIKE/raw_data/Chicago_weather.csv'
df_weather=pd.read_csv(path_weather)

# df_weather['dt']=pd.to_datetime(df_weather['dt'])
df_weather['dt_iso']=df_weather['dt_iso'].apply(lambda x: x.rstrip('+0000 UTC').join('00'))
df_weather['dt_iso']=pd.to_datetime(df_weather['dt_iso'])
df_weather['hourly_data']=df_weather['dt_iso']

df_weather.tail()
# Out:
#                dt              dt_iso  timezone city_name        lat  \
# 91354  1667242800 2022-10-31 19:00:00    -18000   Chicago  41.878114
# 91355  1667246400 2022-10-31 20:00:00    -18000   Chicago  41.878114
# 91356  1667250000 2022-10-31 21:00:00    -18000   Chicago  41.878114
# 91357  1667253600 2022-10-31 22:00:00    -18000   Chicago  41.878114
# 91358  1667257200 2022-10-31 23:00:00    -18000   Chicago  41.878114
#
#              lon   temp  visibility  dew_point  feels_like  ...  rain_1h  \
# 91354 -87.629798  13.89         NaN      12.11       13.66  ...     0.24
# 91355 -87.629798  14.15      9656.0      12.19       13.92  ...      NaN
# 91356 -87.629798  14.11         NaN      11.81       13.82  ...     0.25
# 91357 -87.629798  13.62         NaN      11.84       13.36  ...     0.14
# 91358 -87.629798  13.38         NaN      11.78       13.12  ...     0.11
#
#        rain_3h  snow_1h  snow_3h  clouds_all  weather_id  weather_main  \
# 91354      NaN      NaN      NaN         100         500          Rain
# 91355      NaN      NaN      NaN         100         701          Mist
# 91356      NaN      NaN      NaN         100         500          Rain
# 91357      NaN      NaN      NaN         100         500          Rain
# 91358      NaN      NaN      NaN         100         500          Rain
#
#        weather_description  weather_icon         hourly_data
# 91354           light rain           10d 2022-10-31 19:00:00
# 91355                 mist           50d 2022-10-31 20:00:00
# 91356           light rain           10d 2022-10-31 21:00:00
# 91357           light rain           10d 2022-10-31 22:00:00
# 91358           light rain           10n 2022-10-31 23:00:00
#
# [5 rows x 29 columns]

# %%
df_weather.dtypes
# Out:
# dt                              int64
# dt_iso                 datetime64[ns]
# timezone                        int64
# city_name                      object
# lat                           float64
# lon                           float64
# temp                          float64
# visibility                    float64
# dew_point                     float64
# feels_like                    float64
# temp_min                      float64
# temp_max                      float64
# pressure                        int64
# sea_level                     float64
# grnd_level                    float64
# humidity                        int64
# wind_speed                    float64
# wind_deg                        int64
# wind_gust                     float64
# rain_1h                       float64
# rain_3h                       float64
# snow_1h                       float64
# snow_3h                       float64
# clouds_all                      int64
# weather_id                      int64
# weather_main                   object
# weather_description            object
# weather_icon                   object
# hourly_data            datetime64[ns]
# dtype: object

# %% [markdown]
# # Merging the two Dataframes

# %%
merge=pd.merge(
    df,
    df_weather,
    how="outer",
    on='hourly_data')
merge
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       E19E6F1B8D4C42ED  electric_bike 2021-01-23 16:14:19
# 1       193312ED6078EDA7   classic_bike 2021-01-23 15:59:38
# 2       1C1CBF8EF4582598   classic_bike 2021-01-23 16:23:47
# 3       0A34DD08B59157A4   classic_bike 2021-01-23 15:57:39
# 4       5FA19661B5347829  electric_bike 2021-01-23 15:44:53
# ...                  ...            ...                 ...
# 480468               NaN            NaN                 NaT
# 480469               NaN            NaN                 NaT
# 480470               NaN            NaN                 NaT
# 480471               NaN            NaN                 NaT
# 480472               NaN            NaN                 NaT
#
#                   ended_at          start_station_name start_station_id  \
# 0      2021-01-23 16:24:44  California Ave & Cortez St            17660
# 1      2021-01-23 16:33:51              Shedd Aquarium            15544
# 2      2021-01-23 16:35:05  California Ave & Cortez St            17660
# 3      2021-01-23 16:25:20       State St & Pearson St     TA1307000061
# 4      2021-01-23 15:53:21        Clinton St & 18th St     TA1307000044
# ...                    ...                         ...              ...
# 480468                 NaT                         NaN              NaN
# 480469                 NaT                         NaN              NaN
# 480470                 NaT                         NaN              NaN
# 480471                 NaT                         NaN              NaN
# 480472                 NaT                         NaN              NaN
#
#                  end_station_name end_station_id  start_lat  start_lng  ...  \
# 0                             NaN            NaN  41.900341 -87.696743  ...
# 1       Lake Shore Dr & Monroe St          13300  41.867226 -87.615355  ...
# 2          Damen Ave & Pierce Ave   TA1305000041  41.900363 -87.696704  ...
# 3        Clark St & 9th St (AMLI)         SL-009  41.897448 -87.628722  ...
# 4        Laflin St & Cullerton St          13307  41.857898 -87.640828  ...
# ...                           ...            ...        ...        ...  ...
# 480468                        NaN            NaN        NaN        NaN  ...
# 480469                        NaN            NaN        NaN        NaN  ...
# 480470                        NaN            NaN        NaN        NaN  ...
# 480471                        NaN            NaN        NaN        NaN  ...
# 480472                        NaN            NaN        NaN        NaN  ...
#
#         wind_gust  rain_1h rain_3h snow_1h  snow_3h clouds_all  weather_id  \
# 0            0.00      NaN     NaN     NaN      NaN         75         803
# 1            0.00      NaN     NaN     NaN      NaN         75         803
# 2            0.00      NaN     NaN     NaN      NaN         75         803
# 3            0.00      NaN     NaN     NaN      NaN         75         803
# 4            0.00      NaN     NaN     NaN      NaN         75         803
# ...           ...      ...     ...     ...      ...        ...         ...
# 480468       1.34     0.24     NaN     NaN      NaN        100         500
# 480469        NaN      NaN     NaN     NaN      NaN        100         701
# 480470       3.58     0.25     NaN     NaN      NaN        100         500
# 480471       2.24     0.14     NaN     NaN      NaN        100         500
# 480472        NaN     0.11     NaN     NaN      NaN        100         500
#
#        weather_main  weather_description  weather_icon
# 0            Clouds        broken clouds           04d
# 1            Clouds        broken clouds           04d
# 2            Clouds        broken clouds           04d
# 3            Clouds        broken clouds           04d
# 4            Clouds        broken clouds           04d
# ...             ...                  ...           ...
# 480468         Rain           light rain           10d
# 480469         Mist                 mist           50d
# 480470         Rain           light rain           10d
# 480471         Rain           light rain           10d
# 480472         Rain           light rain           10n
#
# [480473 rows x 42 columns]
